# %%
import pandas as pd
import math

# %%
import numpy as np
from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.datasets.samples_generator import make_blobs
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('data/manhattan_jan_time.csv')

# %%
df_tmp = df.copy()

# %%
df.head()
# Out:
#        pickup_datetime  pickup_latitude  pickup_longitude  trip_distance  \
# 0  2016-01-01 00:00:00         40.73470         -73.99037           1.10
# 1  2016-01-01 00:00:00         40.78133         -73.96062           1.76
# 2  2016-01-01 00:00:00         40.74305         -73.98012           5.52
# 3  2016-01-01 00:00:00         40.71999         -73.99406           7.45
# 4  2016-01-01 00:00:01         40.74461         -73.97942           1.20
#
#    passenger_count     dropoff_datetime  dropoff_latitude  dropoff_longitude  \
# 0                2  2016-01-01 00:00:00          40.73241          -73.98184
# 1                3  2016-01-01 00:00:00          40.75851          -73.97726
# 2                2  2016-01-01 00:18:30          40.76314          -73.91349
# 3                2  2016-01-01 00:26:45          40.78987          -73.96636
# 4                1  2016-01-01 00:11:55          40.75394          -73.99203
#
#    fare_amount  tolls_amount    ...      pickup_neighborhood  \
# ...

# %%
df_MN = pd.read_csv('data/MN.csv')
# Out:
# /home/joelerll/espol-2017/analisis_datos/proyecto/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (19,22,23,25,63,79) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# pd.set_option('display.max_columns', None)
df_MN.head()
# Out:
#   Borough  Block  Lot   CD  CT2010  CB2010  SchoolDist  Council  ZipCode  \
# 0      MN      1   10  101     5.0  1018.0         2.0      1.0  10004.0
# 1      MN      1  101  101     1.0  1001.0         2.0      1.0  10004.0
# 2      MN      1  201  101     1.0  1000.0         2.0      1.0  10004.0
# 3      MN      1  301  101     NaN     NaN         2.0      1.0  10004.0
# 4      MN      1  401  101     NaN     NaN         2.0      1.0  10004.0
#
#   FireComp  PolicePrct  HealthArea  SanitBoro  SanitDistrict SanitSub  \
# 0     E007         1.0      8100.0        1.0            1.0      NaN
# 1     E007         1.0      8200.0        1.0            1.0      NaN
# 2     E007         1.0      8200.0        1.0            1.0      NaN
# 3     E007         1.0         NaN        1.0            1.0      NaN
# 4     E007         1.0         NaN        1.0            1.0      NaN
#
#                         Address ZoneDist1 ZoneDist2 ZoneDist3 ZoneDist4  \
# ...

# %%
df_MN2 = pd.read_csv('data/MN2.csv')

# %%
df_MN2.shape
# Out:
# (34161, 4)

# %%
df['pickup_datetime'] =  pd.to_datetime(df['pickup_datetime'])
df['dropoff_datetime'] =  pd.to_datetime(df['dropoff_datetime'])

# %%
def setDay(day):
    return day.day

# %%
df['day'] = -1

# %%
df['day'] = df['dropoff_datetime'].apply(setDay)

# %%
df = df[(df['dropoff_place'] == '4,5') & (df['day'] == 5)]

# %%
df.head(5)
# Out:
#             pickup_datetime  pickup_latitude  pickup_longitude  trip_distance  \
# 958579  2016-01-04 16:44:09         40.76329         -73.98263           4.00
# 990640  2016-01-04 18:31:02         40.73937         -73.98483           1.23
# 1013743 2016-01-04 19:38:48         40.76467         -73.97675           3.73
# 1017464 2016-01-04 19:50:51         40.74097         -73.98171           1.75
# 1017840 2016-01-04 19:52:07         40.74771         -73.97301           1.65
#
#          passenger_count    dropoff_datetime  dropoff_latitude  \
# 958579                 6 2016-01-05 16:06:43          40.72139
# 990640                 6 2016-01-05 18:27:56          40.72436
# 1013743                2 2016-01-05 19:37:41          40.72140
# 1017464                1 2016-01-05 19:12:36          40.72265
# 1017840                1 2016-01-05 19:46:43          40.72793
#
#          dropoff_longitude  fare_amount  tolls_amount ...   \
# ...

# %%
centers = [[1, 1], [-1, -1], [1, -1]]
X, labels_true = make_blobs(n_samples=750, centers=centers, cluster_std=0.4,
                            random_state=0)

X = StandardScaler().fit_transform(X)

# %%
L = df['passenger_count'].as_matrix()
LO = df['trip_distance'].as_matrix()
arr = []
for index,val in enumerate(L):
    arr.append([L[index],LO[index]])

# %%
arr[:2]
# Out:
# array([[  2.46921701e-01,  -8.51401572e-04],
#        [  9.99731962e-01,  -6.40344590e-04]])

# %%
arr = StandardScaler().fit_transform(arr)

# %%
X = arr

# %%
len(arr)
# Out:
# 269970

# %%
db = DBSCAN(eps=0.0001, min_samples=10).fit(X)
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
# core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_
# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
print('Estimated number of clusters: %d' % n_clusters_)
#print("Homogeneity: %0.3f" % metrics.homogeneity_score(labels_true, labels))
#print("Completeness: %0.3f" % metrics.completeness_score(labels_true, labels))
#print("V-measure: %0.3f" % metrics.v_measure_score(labels_true, labels))
#print("Adjusted Rand Index: %0.3f"
#      % metrics.adjusted_rand_score(labels_true, labels))
#print("Adjusted Mutual Information: %0.3f"
#      % metrics.adjusted_mutual_info_score(labels_true, labels))
#print("Silhouette Coefficient: %0.3f"
#      % metrics.silhouette_score(X, labels))

# %%
labels
# Out:
# array([ 0, -1, -1, ..., 37, -1, -1])

# %%
X = StandardScaler().fit_transform(X)

# %%
import matplotlib.pyplot as plt

# Black removed and is used for noise instead.
unique_labels = set(labels)
colors = [plt.cm.Spectral(each)
          for each in np.linspace(0, 1, len(unique_labels))]
for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = [0, 0, 0, 1]

    class_member_mask = (labels == k)

    xy = X[class_member_mask & core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
             markeredgecolor='k', markersize=14)

    xy = X[class_member_mask & ~core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
             markeredgecolor='k', markersize=6)

plt.title('Estimated number of clusters: %d' % n_clusters_)
plt.show()
