# %%
import pandas as pd

# %%
df = pd.read_csv('data/2februarynew.csv', header=0, sep=',')

# %%
df.head()
# Out:
#        pickup_datetime  pickup_latitude  pickup_longitude  trip_distance  \
# 0  2016-02-01 00:00:00         40.72855         -73.98164           0.90
# 1  2016-02-01 00:00:00         40.76731         -73.95347           3.42
# 2  2016-02-01 00:00:01         40.66244         -73.94978           0.00
# 3  2016-02-01 00:00:01         40.75820         -73.99234           1.99
# 4  2016-02-01 00:00:03         40.74739         -73.97695           0.80
#
#    passenger_count     dropoff_datetime  dropoff_latitude  dropoff_longitude  \
# 0                1  2016-02-01 00:06:47          40.73955          -73.98048
# 1                1  2016-02-01 19:50:51           0.00000            0.00000
# 2                3  2016-02-01 00:03:16          40.66258          -73.94825
# 3                6  2016-02-01 00:10:52          40.75798          -73.96436
# 4                1  2016-02-01 00:03:59          40.74481          -73.98694
#
# ...

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#        pickup_datetime  pickup_latitude  pickup_longitude  trip_distance  \
# 0  2016-02-01 00:00:00         40.72855         -73.98164           0.90
# 3  2016-02-01 00:00:01         40.75820         -73.99234           1.99
# 4  2016-02-01 00:00:03         40.74739         -73.97695           0.80
# 5  2016-02-01 00:00:03         40.75476         -73.96861           1.00
# 6  2016-02-01 00:00:03         40.72710         -74.00329           3.13
#
#    passenger_count     dropoff_datetime  dropoff_latitude  dropoff_longitude  \
# 0                1  2016-02-01 00:06:47          40.73955          -73.98048
# 3                6  2016-02-01 00:10:52          40.75798          -73.96436
# 4                1  2016-02-01 00:03:59          40.74481          -73.98694
# 5                1  2016-02-01 00:05:38          40.76253          -73.97711
# 6                2  2016-02-01 00:11:06          40.75589          -73.97119
#
# ...

# %%
df = df.reset_index(drop=True)

# %%
df.head()
# Out:
#        pickup_datetime  pickup_latitude  pickup_longitude  trip_distance  \
# 0  2016-02-01 00:00:00         40.72855         -73.98164           0.90
# 1  2016-02-01 00:00:01         40.75820         -73.99234           1.99
# 2  2016-02-01 00:00:03         40.74739         -73.97695           0.80
# 3  2016-02-01 00:00:03         40.75476         -73.96861           1.00
# 4  2016-02-01 00:00:03         40.72710         -74.00329           3.13
#
#    passenger_count     dropoff_datetime  dropoff_latitude  dropoff_longitude  \
# 0                1  2016-02-01 00:06:47          40.73955          -73.98048
# 1                6  2016-02-01 00:10:52          40.75798          -73.96436
# 2                1  2016-02-01 00:03:59          40.74481          -73.98694
# 3                1  2016-02-01 00:05:38          40.76253          -73.97711
# 4                2  2016-02-01 00:11:06          40.75589          -73.97119
#
# ...

# %%
pickups = df.loc[: , ['pickup_datetime','pickup_neighborhood'] ]

# %%
pickups.head()
# Out:
#        pickup_datetime pickup_neighborhood
# 0  2016-02-01 00:00:00        East Village
# 1  2016-02-01 00:00:01             Clinton
# 2  2016-02-01 00:00:03         Murray Hill
# 3  2016-02-01 00:00:03             Midtown
# 4  2016-02-01 00:00:03                Soho

# %%
pickups['dummy'] = 1

# %%
pickups.head()
# Out:
#        pickup_datetime pickup_neighborhood  dummy
# 0  2016-02-01 00:00:00        East Village      1
# 1  2016-02-01 00:00:01             Clinton      1
# 2  2016-02-01 00:00:03         Murray Hill      1
# 3  2016-02-01 00:00:03             Midtown      1
# 4  2016-02-01 00:00:03                Soho      1

# %%
pickups_groups = pickups.groupby(['pickup_neighborhood'])

# %%
sum_ = pickups_groups.sum()
sum_.sort_values('dummy', inplace=True, ascending=False)

# %%
sum_
# Out:
#                              dummy
# pickup_neighborhood
# Midtown                    1781515
# Upper East Side            1495828
# Upper West Side             927867
# Gramercy                    869782
# Chelsea                     745126
# Garment District            647054
# Greenwich Village           507682
# East Village                381396
# Murray Hill                 365451
# Clinton                     319001
# West Village                256465
# Lower East Side             250141
# Soho                        221241
# Financial District          214166
# Tribeca                     175599
# Central Park                142318
# Carnegie Hill               131036
# North Sutton Area           106436
# Battery Park                 94814
# Little Italy                 92080
# Yorkville                    72935
# Morningside Heights          57415
# Harlem                       56239
# Astoria-Long Island City     41117
# Chinatown                    33786
# ...

# %%
import matplotlib.pyplot

# %%
pickup_plot = sum_.plot(kind='bar', figsize = (15,12))

# %%
pickup_fig = pickup_plot.get_figure()

# %%
pickup_fig

# %%
pickup_fig.savefig('febpickups')

# %% [markdown]
# Let's see how many dropoffs we have for each neighborhood

# %%
dropoffs = df.loc[: , ['dropoff_datetime','dropoff_neighborhood'] ]
dropoffs['dummy'] = 1
dropoffs_groups = dropoffs.groupby(['dropoff_neighborhood'])

# %%
sum_2 = dropoffs_groups.sum()
sum_2.sort_values('dummy',inplace=True, ascending=False)
sum_2
# Out:
#                                dummy
# dropoff_neighborhood
# Midtown                      1641229
# Upper East Side              1415134
# Upper West Side               906706
# Gramercy                      807538
# Chelsea                       677135
# Garment District              532714
# Greenwich Village             416712
# Murray Hill                   355674
# Clinton                       350207
# East Village                  348949
# West Village                  236055
# Financial District            226471
# Lower East Side               221943
# Soho                          213904
# Tribeca                       166593
# Carnegie Hill                 142104
# Yorkville                     127980
# Harlem                        126390
# Central Park                  122641
# Battery Park                   98420
# Morningside Heights            88316
# North Sutton Area              88300
# Astoria-Long Island City       83817
# Williamsburg                   77467
# ...

# %%
dropoff_plot = sum_2.plot(kind='bar', figsize = (15,12))
dropoff_fig = dropoff_plot.get_figure()
dropoff_fig

# %%
dropoff_fig.savefig('febdropoffs')

# %%
sum_
# Out:
#                              dummy
# pickup_neighborhood
# Midtown                    1781515
# Upper East Side            1495828
# Upper West Side             927867
# Gramercy                    869782
# Chelsea                     745126
# Garment District            647054
# Greenwich Village           507682
# East Village                381396
# Murray Hill                 365451
# Clinton                     319001
# West Village                256465
# Lower East Side             250141
# Soho                        221241
# Financial District          214166
# Tribeca                     175599
# Central Park                142318
# Carnegie Hill               131036
# North Sutton Area           106436
# Battery Park                 94814
# Little Italy                 92080
# Yorkville                    72935
# Morningside Heights          57415
# Harlem                       56239
# Astoria-Long Island City     41117
# Chinatown                    33786
# ...

# %% [markdown]
# Here we are going to see the total pickups that have a value equal or greater than 25000

# %%
sum_drop = sum_.loc[ sum_['dummy']>=25000 , :]

# %%
pickup_plot2 = sum_drop.plot(kind='bar', figsize = (15,12))
pickup_fig2 = pickup_plot2.get_figure()
pickup_fig2

# %% [markdown]
# Here we are going to see the total dropoffs that have a value equal or greater than 25000

# %%
sum_2_drop = sum_2.loc[ sum_2['dummy']>=25000 , :]
dropoff_plot2 = sum_2_drop.plot(kind='bar', figsize = (15,12))
dropoff_fig2 = dropoff_plot2.get_figure()
dropoff_fig2
