# %%
import pandas as pd

# %%
std_jan = pd.read_csv('std_dev_jan.csv')

# %%
std_jan = std_jan.set_index(['pickups_place','pick_weekgroup'])
std_jan.head(20)
# Out:
#                                std_dev   variance
# pickups_place pick_weekgroup
# 0,10          0               0.079331   0.006293
#               1               0.213809   0.045714
#               2               0.075593   0.005714
#               3               0.070711   0.005000
# 0,11          0               0.047246   0.002232
#               1               0.282843   0.080000
#               2               0.000000   0.000000
#               3               0.066667   0.004444
# 0,12          0               0.055902   0.003125
#               1               0.070711   0.005000
#               2                    NaN        NaN
#               3               0.000000   0.000000
# 0,13          0               0.000000   0.000000
#               1               0.000000   0.000000
# 0,4           0               8.624655  74.384665
#               1               6.915468  47.823696
#               2               1.468780   2.157316
#               3               1.623380   2.635362
# 0,5           0               2.616412   6.845611
#               1               2.482577   6.163188

# %%
index = std_jan.index.get_level_values('pickups_place').unique()
index.size
# Out:
# 165

# %%
std_jan.loc['0,10','std_dev'].size
# Out:
# 4

# %%
diff_up = pd.DataFrame(columns=['pickups_place','std_dev_diff','std_dev_percent', 'variance_diff','variance_percent'])
diff_down = pd.DataFrame(columns=['pickups_place','std_dev_diff','std_dev_percent', 'variance_diff','variance_percent'])

# %%
index = std_jan.index.get_level_values('pickups_place').unique()
error_cnt = 0
i_up=0
i_down=0
for i in range (index.size):
        
        try:
            std_0 = std_jan.loc[ (index[i],0) ,'std_dev' ]       
            std_2 = std_jan.loc[ (index[i],2) ,'std_dev' ]
            var_0 = std_jan.loc[ (index[i],0) ,'variance' ]       
            var_2 = std_jan.loc[ (index[i],2) ,'variance' ] 
            std_diff = (std_2 - std_0)
            var_diff = (var_2 - var_0)
            
            if std_diff >0:
                diff_up.loc[i_up]=[ index[i],std_diff,abs(std_diff/std_0)*100,var_diff, abs(var_diff/var_0)*100]
                i_up+=1
            else:
                diff_down.loc[i_down]=[ index[i],std_diff,abs(std_diff/std_0)*100,var_diff, abs(var_diff/var_0)*100]
                i_down+=1
        except KeyError:
            error_cnt+=1
# Out:
# /usr/lib/python2.7/site-packages/ipykernel_launcher.py:19: RuntimeWarning: invalid value encountered in double_scalars
# /usr/lib/python2.7/site-packages/ipykernel_launcher.py:16: RuntimeWarning: divide by zero encountered in double_scalars
#   app.launch_new_instance()

# %%
diff_up = diff_up.sort_values('std_dev_percent', ascending=False)
diff_up
# Out:
#    pickups_place  std_dev_diff  std_dev_percent  variance_diff  \
# 19         17,12      0.282843              inf       0.080000
# 26          2,11      0.726530       906.930189       0.644249
# 15         16,11      0.095706       484.237395       0.012943
# 24         19,11      0.143027       339.428200       0.032510
# 31          3,10      0.153294       315.969051       0.038374
# 27          2,12      0.073967       313.118224       0.008966
# 16         16,12      0.133961       298.189451       0.029982
# 37          4,12      0.074718       295.530586       0.009361
# 23         18,12      0.137533       260.951125       0.033413
# 5           1,12      0.120086       254.175098       0.025768
# 33           3,5    114.837052       247.494881   23844.373662
# 40           4,6     61.426361       222.704112    7161.727867
# 36           3,9      1.186349       208.627538       2.756644
# 4           1,11      0.220051       196.479207       0.097713
# 25          2,10      0.478434       195.834410       0.462668
# 2            0,9      0.128409       194.690737       0.033428
# 34           3,7      1.789645       177.219871       6.817357
# 3           1,10      0.522914       174.522907       0.586796
# 6            1,8      0.211456       164.063199       0.099221
# 1            0,8      0.351005       157.444190       0.279710
# 35           3,8      3.115929       153.722381      22.340898
# 39           4,5    307.671891       151.007933  220035.528359
# 14         15,12      0.058007       146.546929       0.007957
# 18         17,11      0.109890       145.985957       0.028620
# 21         18,10      0.110856       115.832721       0.033508
# 41           4,7      0.043447       113.725130       0.005207
# 13         15,10      0.255616       105.627335       0.189056
# 43          5,12      0.089619        84.898116       0.026952
# 22         18,11      0.588916        83.313547       1.179391
# 49           6,8      0.732188        80.352311       1.870471
# 9          12,11      0.187603        71.920699       0.133066
# 30           2,9      0.184391        71.576263       0.129003
# 51          7,11      0.266510        65.662920       0.287367
# 48           6,3     51.519694        65.494216   10759.662777
# 45           5,4     99.376322        53.754038   46619.509497
# 7            1,9      0.036679        52.230005       0.006497
# 8          10,10      0.056203        50.256716       0.015729
# 53          7,13      0.036413        46.059349       0.007083
# 10         13,11      0.192945        44.050361       0.206251
# 32           3,4     20.133886        43.856482    2254.009511
# 29           2,8      0.373115        43.081407       0.785503
# 54           7,9      0.289997        38.032354       0.526345
# 38           4,4     51.886505        27.666205   22154.289006
# 50           6,9      0.125165        27.116387       0.131215
# 47          6,10      0.112024        25.575654       0.110684
# 28           2,7      0.046139        25.477513       0.018840
# 56          9,12      0.032556        22.319780       0.010557
# 0            0,7      0.125287        20.843492       0.166314
# 55          8,12      0.098917        19.871623       0.108262
# 11         14,11      0.037155        14.638271       0.020242
# 52          7,12      0.037722        13.090833       0.023163
# 42          5,10      0.018663         9.571906       0.007626
# 44           5,3      3.432490         4.156341     578.722480
# 46           5,5     12.043570         3.987592    7419.993922
# 20          17,9      0.001687         1.715849       0.000335
# 17         17,10      0.008532         0.531480       0.027466
# 12         14,12      0.000230         0.383519       0.000028
# 57           9,6      0.446565         0.236508     168.836390
#
#     variance_percent
# 19               inf
# 26      1.003908e+04
# 15      3.313333e+03
# 24      1.830971e+03
# 31      1.630303e+03
# 27      1.606667e+03
# 16      1.485548e+03
# 37      1.464444e+03
# 23      1.202857e+03
# 5       1.154400e+03
# 33      1.107527e+03
# 40      9.413794e+02
# 36      8.525096e+02
# 4       7.789992e+02
# 25      7.751800e+02
# 2       7.684263e+02
# 34      6.685086e+02
# 3       6.536283e+02
# 6       5.972937e+02
# 1       5.627751e+02
# 35      5.437505e+02
# 39      5.300498e+02
# 14      5.078539e+02
# 18      5.050909e+02
# 21      3.658376e+02
# 41      3.567843e+02
# 13      3.228260e+02
# 43      2.418731e+02
# 22      2.360386e+02
# 49      2.252696e+02
# 9       1.955673e+02
# 30      1.943841e+02
# 51      1.744420e+02
# 48      1.738834e+02
# 45      1.364030e+02
# 7       1.317397e+02
# 8       1.257708e+02
# 53      1.133333e+02
# 10      1.075051e+02
# 32      1.069469e+02
# 29      1.047229e+02
# 54      9.052931e+01
# 38      6.298660e+01
# 50      6.158576e+01
# 47      5.769245e+01
# 28      5.744606e+01
# 56      4.962129e+01
# 0       4.603150e+01
# 55      4.369206e+01
# 11      3.141933e+01
# 52      2.789537e+01
# 42      2.006003e+01
# 44      8.485433e+00
# 46      8.134193e+00
# 20      3.461140e+00
# 17      1.065784e+00
# 12      7.685098e-01
# 57      4.735752e-01

# %%
diff_down = diff_down.sort_values('std_dev_percent', ascending=False)
diff_down
# Out:
#    pickups_place  std_dev_diff  std_dev_percent  variance_diff  \
# 83          9,10     -0.023623       100.000000      -0.000558
# 59           5,9     -0.039402       100.000000      -0.001552
# 6            1,4     -0.109449       100.000000      -0.011979
# 44         19,13     -0.062500       100.000000      -0.003906
# 49           2,6     -0.043700       100.000000      -0.001910
# 1           0,11     -0.047246       100.000000      -0.002232
# 22         12,12     -0.046501       100.000000      -0.002162
# 82           8,9     -1.071919        83.168673      -1.614074
# 3            0,4     -7.155874        82.969979     -72.227349
# 68           7,3    -21.667579        78.978168    -719.411610
# 30          13,7     -2.656963        72.677286     -12.367393
# 21         12,10     -7.902324        72.397221    -110.064651
# 40          16,9     -1.187592        70.086674      -2.614283
# 48           2,5     -2.571956        69.890912     -12.314423
# 28         13,10     -3.276037        63.800671     -22.911168
# 55           3,6     -2.947298        62.937995     -18.916997
# 85           9,4     -4.325413        58.994576     -44.717635
# 66           6,7    -17.262743        58.022043    -729.201431
# 27          12,9     -6.055282        57.822917     -90.156761
# 61          6,12     -3.002150        57.084822     -22.564334
# 31          13,8     -7.251420        54.803707    -139.313006
# 38          15,9     -3.359276        53.248684     -31.100299
# 7            1,5     -2.537063        53.025895     -17.840842
# 62          6,13     -0.352568        51.798878      -0.355645
# 60          6,11     -3.119332        51.527915     -28.036603
# 26          12,8     -9.716623        49.101884    -290.145831
# 5            0,6     -1.556529        47.621399      -7.752402
# 33         14,10     -0.783643        46.717124      -2.014905
# 56           4,3    -37.072762        46.187666   -4576.938021
# 19          11,8     -9.996068        45.401556    -340.245793
# ..           ...           ...              ...            ...
# 12          10,7    -12.789715        20.377028   -1441.925344
# 65           6,6    -52.619217        19.562089  -25538.848845
# 54           3,3    -27.992792        19.486842   -7258.716616
# 47           2,4     -2.050653        18.656686     -40.874397
# 14          10,9    -13.062832        18.155497   -1709.096979
# 89           9,9    -21.762426        17.912039   -4814.496158
# 20          11,9     -2.581511        17.508034     -69.463120
# 75          8,11     -0.592983        17.198285      -3.737482
# 10          10,5     -2.372988        16.813705     -61.350847
# 17          11,6     -9.631656        16.596496   -1025.163590
# 69           7,4    -19.089827        14.956690   -4508.601838
# 9            1,7     -0.053516        13.511210      -0.039529
# 63           6,4    -25.696233        13.017908   -9484.135493
# 11          10,6    -22.550054        11.095121   -8657.775226
# 36          14,9     -0.458850        11.029229      -3.607372
# 43         19,12     -0.020398        10.997487      -0.007151
# 78           8,5    -18.654541         8.443216   -7895.121312
# 0           0,10     -0.003738         4.712000      -0.000579
# 29         13,12     -0.002021         3.095960      -0.000260
# 2           0,12           NaN              NaN            NaN
# 16         11,11           NaN              NaN            NaN
# 23         12,13      0.000000              NaN       0.000000
# 24          12,6           NaN              NaN            NaN
# 34         14,13           NaN              NaN            NaN
# 41         17,13           NaN              NaN            NaN
# 42         18,13           NaN              NaN            NaN
# 50         20,12      0.000000              NaN       0.000000
# 51          3,11           NaN              NaN            NaN
# 52          3,12           NaN              NaN            NaN
# 76          8,13      0.000000              NaN       0.000000
#
#     variance_percent
# 83        100.000000
# 59        100.000000
# 6         100.000000
# 44        100.000000
# 49        100.000000
# 1         100.000000
# 22        100.000000
# 82         97.167064
# 3          97.099784
# 68         95.580826
# 30         92.534693
# 21         92.380866
# 40         91.051929
# 48         90.934428
# 28         86.896086
# 55         86.264078
# 85         83.185552
# 66         82.378511
# 27         82.210937
# 61         81.582875
# 31         79.572951
# 38         78.143144
# 7          77.934335
# 62         76.766518
# 60         76.504570
# 26         74.093818
# 5          72.564821
# 33         71.609352
# 56         71.042328
# 19         70.190100
# ..               ...
# 12         36.601823
# 65         35.297426
# 54         35.176314
# 47         33.832653
# 14         33.014774
# 89         32.615666
# 20         31.950756
# 75         31.438760
# 10         30.800403
# 17         30.438555
# 69         27.676354
# 9          25.196892
# 63         24.341156
# 11         20.959225
# 36         20.842020
# 43         20.785527
# 78         16.173553
# 0           9.201970
# 29          6.096070
# 2                NaN
# 16               NaN
# 23               NaN
# 24               NaN
# 34               NaN
# 41               NaN
# 42               NaN
# 50               NaN
# 51               NaN
# 52               NaN
# 76               NaN
#
# [90 rows x 5 columns]

# %%
error_cnt
# Out:
# 17

# %%
diff=None

# %%
std_jan.loc['2,11']
# Out:
#                  std_dev  variance
# pick_weekgroup
# 0               0.080109  0.006417
# 1               1.345581  1.810588
# 2               0.806639  0.650667
# 3               0.738596  0.545524

# %% [markdown]
# diff=diff.sort_values('std_dev_percent')
